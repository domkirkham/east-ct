# %%
# %run ct_include.ipy

# %%
import seaborn as sns

sns.set()

# %%
photon_source = source.photons[0] 
coeff = 
y = photons(source.photons[0], coeff, [0.0, 0.1, 200])

# %%
depths = np.linspace(0.0, 5., 100)
material_coeff = material.coeff('Water')

source_idxs = [0, 3, 4, 7]
source_names = np.array(source.name)[source_idxs]
photon_sources = source.photons[source_idxs, :]

photon_counts = []
for photon_source, source_name in zip(photon_sources, source_names):
    photon_counts.append(ct_detect(photon_source, material_coeff, depths))

# %%
fig, ax = plt.subplots()

for photon_count, source_name in zip(photon_counts, source_names):
    ax.plot(depths, photon_count, label=source_name)
    ax.set_xscale('linear')
    ax.set_yscale('log')
plt.legend()

# %% [markdown]
# ## Distribution with depth

# %%
depths = np.linspace(0.0, 5., 100)
material_coeff = material.coeff('Water')
photon_source = source.photons[0]

detector_photons = photons(np.repeat(photon_source[:, None], len(depths), axis=1), material_coeff, depths)

# %%
sns.heatmap(detector_photons[:100, :])

# %%
# Out:
# True
